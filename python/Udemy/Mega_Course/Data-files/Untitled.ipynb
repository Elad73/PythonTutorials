# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'BenchmarkEmail_Users_All_08_05_to_11_08_2015_Group4.csv',
#  'Fusic-live-2016_06_14-returnRate.csv',
#  'Only_Sing_Users_Prod.csv',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df2=pandas.read_csv("Only_Sing_Users_Prod.csv", sep=';')
df2.set_index("id")
# Out:
#             kind  numfuses
# id
# 80          sing         2
# 100         sing        10
# 105         sing         4
# 122         sing        14
# 125         sing         4
# 135         sing         1
# 176         sing         5
# 222         sing        77
# 296         sing         9
# 299         sing        28
# 345         sing         4
# 370         sing         1
# 373         sing         2
# 374         sing         7
# 413         sing        62
# 444         sing         1
# 449         sing         6
# 464         sing         1
# 504         sing         1
# 553         sing        11
# 579         sing         1
# 580         sing         2
# 586         sing         5
# 607         sing         9
# 638         sing        14
# 657         sing         1
# 728         sing         2
# 766         sing         5
# 860         sing         1
# 917         sing         1
# ...          ...       ...
# 3147550098  sing         3
# 3147550099  sing         1
# ...

# %%
df1=pandas.read_csv("BenchmarkEmail_Users_All_08_05_to_11_08_2015_Group4.csv")
df1.set_index("id")
# Out:
#                                          email       first_name  \
# id
# 3147642408             adrianbec05@hotmail.com          Rebecca
# 3147639392         suniai.mikas13579@gmail.com           Suniai
# 3147639310         tw3245644675@null.fusic.com  LEELO_LYNCHCREW
# 3147629537          ellizabethmaslow@gmail.com             lisa
# 3147636132                  chjghh75@gmail.com              Chj
# 3147629361   fb1664041860473962@null.fusic.com       Rosangelah
# 3147641554            shyannturner67@gmail.com          Shy'Ann
# 3147642368            amiyah.ramirez@gmail.com           Amiyah
# 3147636979                wendylea99@gmail.com            Wendy
# 3147629362   fb1478432589143355@null.fusic.com        Gabriella
# 3147637721                dimplez646@gmail.com         Josefina
# 3147642372         taquillecandelria@gmail.com         Taquille
# 3147629348         thainaandreazzi02@gmail.com           Thaina
# 3147633486          fernanda_mafis@hotmail.com         Fernanda
# ...
